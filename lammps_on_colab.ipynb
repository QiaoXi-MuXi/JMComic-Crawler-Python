# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/jingjieyeo/lammps_on_colab/blob/main/lammps_on_colab.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# First, get all the libraries and executables that we will need

# We start with installing Anaconda
# !pip install -q condacolab
import condacolab
condacolab.install()

# Then we get the packages needed for LAMMPS
# !conda install -c conda-forge lammps

# Get packages needed for MD trajectory analyses and visualization
# !pip install mdtraj
# !pip install py3dmol
# !pip install lammps-logfile
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - lammps
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ase-3.25.0                 |     pyhd8ed1ab_0         1.8 MB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     binutils_impl_linux-64-2.43|       h4bf12b8_2         5.4 MB  conda-forge
#     binutils_linux-64-2.43     |       h4852527_2          34 KB  conda-forge
#     blinker-1.9.0              |     pyhff2d567_0          14 KB  conda-forge
#     blosc-1.21.6               |       he440d0b_1          47 KB  conda-forge
#     brotli-1.1.0               |       hb9d3cd8_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hb9d3cd8_2          18 KB  conda-forge
#     ca-certificates-2025.4.26  |       hbd8a1cb_0         149 KB  conda-forge
#     certifi-2025.1.31          |     pyhd8ed1ab_0         159 KB  conda-forge
#     click-8.1.8                |     pyh707e725_0          83 KB  conda-forge
#     cmake-3.31.5               |       h74e3db0_0        19.4 MB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     contourpy-1.3.2            |  py311hd18a35c_0         272 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     f90wrap-0.2.16             |  py311hcc61034_1         298 KB  conda-forge
#     fftw-3.3.10                |mpi_openmpi_h99e62ba_10         2.0 MB  conda-forge
#     flask-3.1.0                |     pyhd8ed1ab_1          80 KB  conda-forge
#     fonttools-4.57.0           |  py311h2dc5d0c_0         2.8 MB  conda-forge
#     freetype-2.13.3            |       ha770c72_1         168 KB  conda-forge
#     gawk-5.3.1                 |       hcd3d067_0         1.1 MB  conda-forge
#     gcc_impl_linux-64-13.3.0   |       h1e990d8_2        63.7 MB  conda-forge
#     gcc_linux-64-13.3.0        |      hc28eda2_10          32 KB  conda-forge
#     gfortran_impl_linux-64-13.3.0|       h84c1745_2        15.2 MB  conda-forge
#     gfortran_linux-64-13.3.0   |      hb919d3a_10          30 KB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     gsl-2.7                    |       he838d99_0         3.2 MB  conda-forge
#     gxx_impl_linux-64-13.3.0   |       hae580e1_2        12.7 MB  conda-forge
#     gxx_linux-64-13.3.0        |      h6834431_10          30 KB  conda-forge
#     hdf4-4.2.15                |       h2a13503_7         739 KB  conda-forge
#     hdf5-1.14.3                |mpi_openmpi_h39ae36c_9         3.8 MB  conda-forge
#     importlib-metadata-8.6.1   |     pyha770c72_0          28 KB  conda-forge
#     itsdangerous-2.2.0         |     pyhd8ed1ab_1          19 KB  conda-forge
#     jinja2-3.1.6               |     pyhd8ed1ab_0         110 KB  conda-forge
#     kernel-headers_linux-64-3.10.0|      he073ed8_18         921 KB  conda-forge
#     kim-api-2.4.1              |       hb61eb52_0         779 KB  conda-forge
#     kiwisolver-1.4.7           |  py311hd18a35c_0          71 KB  conda-forge
#     lammps-2024.08.29          |cpu_py311_h81f0c5c_mpi_openmpi_0        21.7 MB  conda-forge
#     lcms2-2.17                 |       h717163a_0         242 KB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     libaec-1.1.3               |       h59595ed_0          35 KB  conda-forge
#     libasprintf-0.24.1         |       h8e693c7_0          52 KB  conda-forge
#     libblas-3.9.0              |31_h59b9bed_openblas          16 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hb9d3cd8_2          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       hb9d3cd8_2          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hb9d3cd8_2         275 KB  conda-forge
#     libcap-2.71                |       h39aace5_0         100 KB  conda-forge
#     libcblas-3.9.0             |31_he106b2a_openblas          16 KB  conda-forge
#     libdeflate-1.23            |       h86f0d12_0          71 KB  conda-forge
#     libevent-2.1.12            |       hf998b51_1         417 KB  conda-forge
#     libfabric-2.1.0            |       ha770c72_0          14 KB  conda-forge
#     libfabric1-2.1.0           |       h14e6f36_0         656 KB  conda-forge
#     libfreetype-2.13.3         |       ha770c72_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h48d6fc4_1         371 KB  conda-forge
#     libgcc-devel_linux-64-13.3.0|     hc03c837_102         2.5 MB  conda-forge
#     libgcrypt-lib-1.11.0       |       hb9d3cd8_2         572 KB  conda-forge
#     libgettextpo-0.24.1        |       h5888daf_0         167 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_2          52 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_2          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hf1ad2bd_2         1.4 MB  conda-forge
#     libgpg-error-1.55          |       h3f2d84a_0         305 KB  conda-forge
#     libhwloc-2.11.2            |default_h0d58e46_1001         2.3 MB  conda-forge
#     libidn2-2.3.8              |       ha4ef2c3_0         135 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       hb9d3cd8_0         614 KB  conda-forge
#     liblapack-3.9.0            |31_h7ac8fdf_openblas          16 KB  conda-forge
#     libnetcdf-4.9.2            |mpi_openmpi_ha1e512f_14         840 KB  conda-forge
#     libnl-3.11.0               |       hb9d3cd8_0         724 KB  conda-forge
#     libopenblas-0.3.29         |pthreads_h94d23a6_0         5.6 MB  conda-forge
#     libpmix-5.0.7              |       h658e747_0         709 KB  conda-forge
#     libpnetcdf-1.13.0          |mpi_openmpi_h521bef2_1         2.3 MB  conda-forge
#     libpng-1.6.47              |       h943b412_0         282 KB  conda-forge
#     libsanitizer-13.3.0        |       he8ea267_2         4.0 MB  conda-forge
#     libstdcxx-devel_linux-64-13.3.0|     hc03c837_102        12.3 MB  conda-forge
#     libsystemd0-257.2          |       h3dc2cb9_0         476 KB  conda-forge
#     libtiff-4.7.0              |       hd9ff511_3         418 KB  conda-forge
#     libudev1-257.4             |       h9a4d06a_0         140 KB  conda-forge
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     libuv-1.50.0               |       hb9d3cd8_0         870 KB  conda-forge
#     libwebp-base-1.5.0         |       h851e524_0         420 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libzip-1.11.2              |       h6991a6a_0         106 KB  conda-forge
#     make-4.4.1                 |       hb9d3cd8_2         501 KB  conda-forge
#     markupsafe-3.0.2           |  py311h2dc5d0c_1          25 KB  conda-forge
#     matplotlib-base-3.10.1     |  py311h2b939e6_0         8.0 MB  conda-forge
#     mlip-3.0                   |mpi_openmpi_h312e9eb_2         1.0 MB  conda-forge
#     mpfr-4.2.1                 |       h90cbb55_3         620 KB  conda-forge
#     mpi-1.0                    |          openmpi           4 KB  conda-forge
#     mpi4py-4.0.3               |  py311ha982e2a_0         852 KB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     n2p2-2.2.0                 |mpi_openmpi_py311_h819e8d0_106         9.0 MB  conda-forge
#     numpy-1.26.4               |  py311h64a7726_0         7.7 MB  conda-forge
#     openjpeg-2.5.3             |       h5fbd93e_0         335 KB  conda-forge
#     openmpi-5.0.7              |     hb85ec53_100         3.4 MB  conda-forge
#     openssl-3.5.0              |       h7b32b05_1         3.0 MB  conda-forge
#     pillow-11.1.0              |  py311h1322bbf_0        40.1 MB  conda-forge
#     pkg-config-0.29.2          |    h4bc722e_1009         112 KB  conda-forge
#     plumed-2.9.2               |mpi_openmpi_h02da92d_0         3.5 MB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pyparsing-3.2.3            |     pyhd8ed1ab_1          94 KB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhff2d567_1         217 KB  conda-forge
#     qhull-2020.2               |       h434a139_5         540 KB  conda-forge
#     quippy-0.9.14              |  py311h4189ce2_0         6.4 MB  conda-forge
#     rdma-core-56.0             |       h5888daf_0         1.2 MB  conda-forge
#     rhash-1.4.5                |       hb9d3cd8_0         183 KB  conda-forge
#     scipy-1.15.2               |  py311h8f841c2_0        16.4 MB  conda-forge
#     six-1.17.0                 |     pyhd8ed1ab_0          16 KB  conda-forge
#     snappy-1.2.1               |       h8bd8927_1          42 KB  conda-forge
#     sysroot_linux-64-2.17      |      h0157908_18        14.5 MB  conda-forge
#     ucc-1.3.0                  |       had72a48_5         7.7 MB  conda-forge
#     ucx-1.18.0                 |       hfd9a62f_3         7.2 MB  conda-forge
#     unicodedata2-16.0.0        |  py311h9ecbd09_0         396 KB  conda-forge
#     voro-0.4.6                 |       h00ab1b0_0         201 KB  conda-forge
#     werkzeug-3.1.3             |     pyhd8ed1ab_1         238 KB  conda-forge
#     wget-1.21.4                |       hda4d442_0         752 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xz-tools-5.6.3             |       hb9d3cd8_1          88 KB  conda-forge
#     zipp-3.21.0                |     pyhd8ed1ab_1          21 KB  conda-forge
#     zlib-1.3.1                 |       hb9d3cd8_2          90 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       334.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   ase                conda-forge/noarch::ase-3.25.0-pyhd8ed1ab_0
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   binutils_impl_lin~ conda-forge/linux-64::binutils_impl_linux-64-2.43-h4bf12b8_2
#   binutils_linux-64  conda-forge/linux-64::binutils_linux-64-2.43-h4852527_2
#   blinker            conda-forge/noarch::blinker-1.9.0-pyhff2d567_0
#   blosc              conda-forge/linux-64::blosc-1.21.6-he440d0b_1
#   brotli             conda-forge/linux-64::brotli-1.1.0-hb9d3cd8_2
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hb9d3cd8_2
#   click              conda-forge/noarch::click-8.1.8-pyh707e725_0
#   cmake              conda-forge/linux-64::cmake-3.31.5-h74e3db0_0
#   contourpy          conda-forge/linux-64::contourpy-1.3.2-py311hd18a35c_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   f90wrap            conda-forge/linux-64::f90wrap-0.2.16-py311hcc61034_1
#   fftw               conda-forge/linux-64::fftw-3.3.10-mpi_openmpi_h99e62ba_10
#   flask              conda-forge/noarch::flask-3.1.0-pyhd8ed1ab_1
#   fonttools          conda-forge/linux-64::fonttools-4.57.0-py311h2dc5d0c_0
#   freetype           conda-forge/linux-64::freetype-2.13.3-ha770c72_1
#   gawk               conda-forge/linux-64::gawk-5.3.1-hcd3d067_0
#   gcc_impl_linux-64  conda-forge/linux-64::gcc_impl_linux-64-13.3.0-h1e990d8_2
#   gcc_linux-64       conda-forge/linux-64::gcc_linux-64-13.3.0-hc28eda2_10
#   gfortran_impl_lin~ conda-forge/linux-64::gfortran_impl_linux-64-13.3.0-h84c1745_2
#   gfortran_linux-64  conda-forge/linux-64::gfortran_linux-64-13.3.0-hb919d3a_10
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   gsl                conda-forge/linux-64::gsl-2.7-he838d99_0
#   gxx_impl_linux-64  conda-forge/linux-64::gxx_impl_linux-64-13.3.0-hae580e1_2
#   gxx_linux-64       conda-forge/linux-64::gxx_linux-64-13.3.0-h6834431_10
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h2a13503_7
#   hdf5               conda-forge/linux-64::hdf5-1.14.3-mpi_openmpi_h39ae36c_9
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.6.1-pyha770c72_0
#   itsdangerous       conda-forge/noarch::itsdangerous-2.2.0-pyhd8ed1ab_1
#   jinja2             conda-forge/noarch::jinja2-3.1.6-pyhd8ed1ab_0
#   kernel-headers_li~ conda-forge/noarch::kernel-headers_linux-64-3.10.0-he073ed8_18
#   kim-api            conda-forge/linux-64::kim-api-2.4.1-hb61eb52_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.7-py311hd18a35c_0
#   lammps             conda-forge/linux-64::lammps-2024.08.29-cpu_py311_h81f0c5c_mpi_openmpi_0
#   lcms2              conda-forge/linux-64::lcms2-2.17-h717163a_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   libaec             conda-forge/linux-64::libaec-1.1.3-h59595ed_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.24.1-h8e693c7_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-31_h59b9bed_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hb9d3cd8_2
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hb9d3cd8_2
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hb9d3cd8_2
#   libcap             conda-forge/linux-64::libcap-2.71-h39aace5_0
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-31_he106b2a_openblas
#   libdeflate         conda-forge/linux-64::libdeflate-1.23-h86f0d12_0
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libfabric          conda-forge/linux-64::libfabric-2.1.0-ha770c72_0
#   libfabric1         conda-forge/linux-64::libfabric1-2.1.0-h14e6f36_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.13.3-ha770c72_1
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.13.3-h48d6fc4_1
#   libgcc-devel_linu~ conda-forge/noarch::libgcc-devel_linux-64-13.3.0-hc03c837_102
#   libgcrypt-lib      conda-forge/linux-64::libgcrypt-lib-1.11.0-hb9d3cd8_2
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.24.1-h5888daf_0
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_2
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_2
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hf1ad2bd_2
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.55-h3f2d84a_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.11.2-default_h0d58e46_1001
#   libidn2            conda-forge/linux-64::libidn2-2.3.8-ha4ef2c3_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.0-hb9d3cd8_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-31_h7ac8fdf_openblas
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.9.2-mpi_openmpi_ha1e512f_14
#   libnl              conda-forge/linux-64::libnl-3.11.0-hb9d3cd8_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.29-pthreads_h94d23a6_0
#   libpmix            conda-forge/linux-64::libpmix-5.0.7-h658e747_0
#   libpnetcdf         conda-forge/linux-64::libpnetcdf-1.13.0-mpi_openmpi_h521bef2_1
#   libpng             conda-forge/linux-64::libpng-1.6.47-h943b412_0
#   libsanitizer       conda-forge/linux-64::libsanitizer-13.3.0-he8ea267_2
#   libstdcxx-devel_l~ conda-forge/noarch::libstdcxx-devel_linux-64-13.3.0-hc03c837_102
#   libsystemd0        conda-forge/linux-64::libsystemd0-257.2-h3dc2cb9_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hd9ff511_3
#   libudev1           conda-forge/linux-64::libudev1-257.4-h9a4d06a_0
#   libunistring       conda-forge/linux-64::libunistring-0.9.10-h7f98852_0
#   libuv              conda-forge/linux-64::libuv-1.50.0-hb9d3cd8_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.5.0-h851e524_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libzip             conda-forge/linux-64::libzip-1.11.2-h6991a6a_0
#   make               conda-forge/linux-64::make-4.4.1-hb9d3cd8_2
#   markupsafe         conda-forge/linux-64::markupsafe-3.0.2-py311h2dc5d0c_1
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.10.1-py311h2b939e6_0
#   mlip               conda-forge/linux-64::mlip-3.0-mpi_openmpi_h312e9eb_2
#   mpfr               conda-forge/linux-64::mpfr-4.2.1-h90cbb55_3
#   mpi                conda-forge/linux-64::mpi-1.0-openmpi
#   mpi4py             conda-forge/linux-64::mpi4py-4.0.3-py311ha982e2a_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   n2p2               conda-forge/linux-64::n2p2-2.2.0-mpi_openmpi_py311_h819e8d0_106
#   numpy              conda-forge/linux-64::numpy-1.26.4-py311h64a7726_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.3-h5fbd93e_0
#   openmpi            conda-forge/linux-64::openmpi-5.0.7-hb85ec53_100
#   pillow             conda-forge/linux-64::pillow-11.1.0-py311h1322bbf_0
#   pkg-config         conda-forge/linux-64::pkg-config-0.29.2-h4bc722e_1009
#   plumed             conda-forge/linux-64::plumed-2.9.2-mpi_openmpi_h02da92d_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.3-pyhd8ed1ab_1
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhff2d567_1
#   qhull              conda-forge/linux-64::qhull-2020.2-h434a139_5
#   quippy             conda-forge/linux-64::quippy-0.9.14-py311h4189ce2_0
#   rdma-core          conda-forge/linux-64::rdma-core-56.0-h5888daf_0
#   rhash              conda-forge/linux-64::rhash-1.4.5-hb9d3cd8_0
#   scipy              conda-forge/linux-64::scipy-1.15.2-py311h8f841c2_0
#   six                conda-forge/noarch::six-1.17.0-pyhd8ed1ab_0
#   snappy             conda-forge/linux-64::snappy-1.2.1-h8bd8927_1
#   sysroot_linux-64   conda-forge/noarch::sysroot_linux-64-2.17-h0157908_18
#   ucc                conda-forge/linux-64::ucc-1.3.0-had72a48_5
#   ucx                conda-forge/linux-64::ucx-1.18.0-hfd9a62f_3
#   unicodedata2       conda-forge/linux-64::unicodedata2-16.0.0-py311h9ecbd09_0
#   voro               conda-forge/linux-64::voro-0.4.6-h00ab1b0_0
#   werkzeug           conda-forge/noarch::werkzeug-3.1.3-pyhd8ed1ab_1
#   wget               conda-forge/linux-64::wget-1.21.4-hda4d442_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xz-tools           conda-forge/linux-64::xz-tools-5.6.3-hb9d3cd8_1
#   zipp               conda-forge/noarch::zipp-3.21.0-pyhd8ed1ab_1
#   zlib               conda-forge/linux-64::zlib-1.3.1-hb9d3cd8_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.4.26-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.1.31-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.5.0-h7b32b05_1
#
#
#
# Downloading and Extracting Packages:
# gcc_impl_linux-64-13 | 63.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
# pillow-11.1.0        | 40.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# lammps-2024.08.29    | 21.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# cmake-3.31.5         | 19.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# scipy-1.15.2         | 16.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# gfortran_impl_linux- | 15.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# n2p2-2.2.0           | 9.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.18.0           | 7.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# quippy-0.9.14        | 6.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | :   1% 0.007361317853219138/1 [00:00<00:13, 13.83s/it]
# pillow-11.1.0        | 40.1 MB   | :   1% 0.013646211310668337/1 [00:00<00:07,  7.54s/it]
#
# lammps-2024.08.29    | 21.7 MB   | :   0% 0.0007213506904233959/1 [00:00<02:33, 153.80s/it]
#
#
#
# scipy-1.15.2         | 16.4 MB   | :   1% 0.005717633896244348/1 [00:00<00:18, 18.47s/it]
#
#
# cmake-3.31.5         | 19.4 MB   | :   0% 0.0008041358023600679/1 [00:00<02:39, 159.49s/it]
# gcc_impl_linux-64-13 | 63.7 MB   | :   9% 0.08637279614443788/1 [00:00<00:01,  2.14s/it]
#
# lammps-2024.08.29    | 21.7 MB   | :  19% 0.18755117951008296/1 [00:00<00:00,  1.05it/s]
#
#
#
# scipy-1.15.2         | 16.4 MB   | :  33% 0.32876394903405/1 [00:00<00:00,  1.79it/s]
#
#
# cmake-3.31.5         | 19.4 MB   | :  24% 0.24445728391746063/1 [00:00<00:00,  1.25it/s]
# gcc_impl_linux-64-13 | 63.7 MB   | :  17% 0.16955568788581415/1 [00:00<00:01,  1.65s/it]
#
# lammps-2024.08.29    | 21.7 MB   | :  42% 0.41910475113599305/1 [00:00<00:00,  1.61it/s]
#
#
#
# scipy-1.15.2         | 16.4 MB   | :  62% 0.6165515218116822/1 [00:00<00:00,  2.26it/s]
#
#
# cmake-3.31.5         | 19.4 MB   | :  48% 0.4808732098113206/1 [00:00<00:00,  1.72it/s]
# gcc_impl_linux-64-13 | 63.7 MB   | :  25% 0.24954867522412877/1 [00:00<00:01,  1.47s/it]
#
# lammps-2024.08.29    | 21.7 MB   | :  62% 0.6218042951449673/1 [00:00<00:00,  1.74it/s]
#
#
#
# scipy-1.15.2         | 16.4 MB   | :  94% 0.9434095928803174/1 [00:00<00:00,  2.58it/s]
#
#
# cmake-3.31.5         | 19.4 MB   | :  73% 0.7277429011358615/1 [00:00<00:00,  2.00it/s]
# pillow-11.1.0        | 40.1 MB   | :  52% 0.5177762463019301/1 [00:00<00:00,  1.11it/s]
#
# gcc_impl_linux-64-13 | 63.7 MB   | :  33% 0.3322408124419571/1 [00:00<00:00,  1.40s/it]
#
#
# cmake-3.31.5         | 19.4 MB   | :  94% 0.935209938144759/1 [00:00<00:00,  1.93it/s]
# gcc_impl_linux-64-13 | 63.7 MB   | :  40% 0.40340021835640877/1 [00:00<00:00,  1.54s/it]
# gcc_impl_linux-64-13 | 63.7 MB   | :  47% 0.46940670177360705/1 [00:00<00:00,  1.54s/it]
# gcc_impl_linux-64-13 | 63.7 MB   | :  64% 0.6389623896594212/1 [00:00<00:00,  1.33s/it]
# pillow-11.1.0        | 40.1 MB   | :  97% 0.9727799205747857/1 [00:00<00:00,  1.08it/s]
#
#
#
# scipy-1.15.2         | 16.4 MB   | : 100% 1.0/1 [00:00<00:00,  2.58it/s]
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | :  71% 0.7147839635475783/1 [00:01<00:00,  1.36s/it]
#
#
#
#
# gfortran_impl_linux- | 15.2 MB   | :  33% 0.33336397931546924/1 [00:01<00:01,  2.40s/it]
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | :  79% 0.7888878966033176/1 [00:01<00:00,  1.46s/it]
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | :   0% 0.001080245621375624/1 [00:01<18:31, 1113.13s/it]
#
#
#
#
# gfortran_impl_linux- | 15.2 MB   | :  62% 0.6193985047775077/1 [00:01<00:00,  1.28s/it]
#
# lammps-2024.08.29    | 21.7 MB   | : 100% 1.0/1 [00:01<00:00,  1.97it/s]
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | :   0% 0.0012260743753598562/1 [00:01<17:45, 1066.54s/it]
#
#
#
#
# gfortran_impl_linux- | 15.2 MB   | :  84% 0.842670058825214/1 [00:01<00:00,  1.03it/s]
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | :  86% 0.8583296616853515/1 [00:01<00:00,  1.58s/it]
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | :  52% 0.5174376526389238/1 [00:01<00:00,  1.76s/it]
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | :  92% 0.9228638815319059/1 [00:01<00:00,  1.73s/it]
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | :  61% 0.605680741427769/1 [00:01<00:00,  1.58s/it]
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | :  99% 0.9898518739962001/1 [00:01<00:00,  1.69s/it]
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | :  96% 0.9600162359067674/1 [00:01<00:00,  1.03it/s]
#
#
#
#
# gfortran_impl_linux- | 15.2 MB   | : 100% 1.0/1 [00:01<00:00,  1.03it/s]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | :   0% 0.0012727285438739451/1 [00:02<26:23, 1585.80s/it]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | :  37% 0.36654582063569624/1 [00:02<00:02,  4.15s/it]
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | : 100% 1.0/1 [00:02<00:00,  1.02s/it]
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | : 100% 1.0/1 [00:02<00:00,  1.03it/s]
#
#
#
#
#
#
#
#
# n2p2-2.2.0           | 9.0 MB    | :   0% 0.0017351654946921452/1 [00:02<20:55, 1257.40s/it]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | :   0% 0.0019426210634474932/1 [00:02<18:50, 1132.88s/it]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | :  65% 0.6465461002879641/1 [00:02<00:00,  2.19s/it]
#
#
#
#
#
#
#
#
# n2p2-2.2.0           | 9.0 MB    | :  36% 0.3609144228959662/1 [00:02<00:02,  4.52s/it]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | :  34% 0.34384392823020626/1 [00:02<00:03,  4.78s/it]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | :  87% 0.8705463240097785/1 [00:02<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
# n2p2-2.2.0           | 9.0 MB    | :  68% 0.6819200394140131/1 [00:02<00:00,  2.19s/it]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | :  77% 0.7692779411252073/1 [00:02<00:00,  1.89s/it]
# pillow-11.1.0        | 40.1 MB   | : 100% 1.0/1 [00:02<00:00,  1.08it/s]
#
#
#
#
#
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | :   0% 0.0020238136559741597/1 [00:02<20:20, 1222.78s/it]
#
#
#
#
#
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | :  31% 0.30964348936404645/1 [00:02<00:04,  5.95s/it]
#
#
#
#
#
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | :  78% 0.7832158848619999/1 [00:02<00:00,  2.01s/it]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | : 100% 1.0/1 [00:02<00:00,  1.89s/it]
#
#
#
#
#
#
#
#
# n2p2-2.2.0           | 9.0 MB    | : 100% 1.0/1 [00:02<00:00,  1.72s/it]
#
#
#
#
#
#
#
#
# n2p2-2.2.0           | 9.0 MB    | : 100% 1.0/1 [00:02<00:00,  1.72s/it]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | : 100% 1.0/1 [00:02<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | :   0% 0.002031269952850832/1 [00:02<22:46, 1369.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.18.0           | 7.2 MB    | :   0% 0.0021851574142908547/1 [00:02<21:20, 1282.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# quippy-0.9.14        | 6.4 MB    | :   0% 0.002456813082769589/1 [00:02<19:21, 1164.10s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | :  48% 0.4834422487784981/1 [00:02<00:02,  4.24s/it]
#
#
#
#
#
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | : 100% 1.0/1 [00:02<00:00,  2.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.18.0           | 7.2 MB    | :  46% 0.4632533718296612/1 [00:02<00:02,  4.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0.0027679004637044184/1 [00:02<17:40, 1063.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# quippy-0.9.14        | 6.4 MB    | :  57% 0.5748942613680837/1 [00:02<00:01,  3.66s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | :  87% 0.8673522698673054/1 [00:02<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.18.0           | 7.2 MB    | :  91% 0.9133957991735773/1 [00:03<00:00,  2.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :  67% 0.6725998126801737/1 [00:03<00:01,  3.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# quippy-0.9.14        | 6.4 MB    | : 100% 1.0/1 [00:03<00:00,  1.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# quippy-0.9.14        | 6.4 MB    | : 100% 1.0/1 [00:03<00:00,  1.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.18.0           | 7.2 MB    | : 100% 1.0/1 [00:03<00:00,  2.00s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | : 100% 1.0/1 [00:03<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.4 MB    | :   0% 0.0028830974715354832/1 [00:03<18:16, 1099.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | :   0% 0.003942877371556269/1 [00:03<13:24, 807.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.8 MB    | :   0% 0.004063430587979696/1 [00:03<13:02, 785.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:03<00:00,  3.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.4 MB    | :  71% 0.7121250754692644/1 [00:03<00:00,  3.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | :  99% 0.9857193428890674/1 [00:03<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | : 100% 1.0/1 [00:03<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.8 MB    | : 100% 1.0/1 [00:03<00:00,  2.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.8 MB    | : 100% 1.0/1 [00:03<00:00,  2.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | : 100% 1.0/1 [00:03<00:00,  1.69s/it]
#
#
#
# scipy-1.15.2         | 16.4 MB   | : 100% 1.0/1 [00:07<00:00,  2.58it/s]
#
#
# cmake-3.31.5         | 19.4 MB   | : 100% 1.0/1 [00:08<00:00,  1.93it/s]
#
# lammps-2024.08.29    | 21.7 MB   | : 100% 1.0/1 [00:08<00:00,  1.97it/s]
#
#
#
#
# gfortran_impl_linux- | 15.2 MB   | : 100% 1.0/1 [00:08<00:00,  1.03it/s]
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | : 100% 1.0/1 [00:09<00:00,  1.03it/s]
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | : 100% 1.0/1 [00:09<00:00,  1.02s/it]
# pillow-11.1.0        | 40.1 MB   | : 100% 1.0/1 [00:10<00:00,  1.08it/s]
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | : 100% 1.0/1 [00:10<00:00,  1.89s/it]
#
#
#
#
#
#
#
#
# n2p2-2.2.0           | 9.0 MB    | : 100% 1.0/1 [00:11<00:00,  1.72s/it]
#
#
#
#
#
#
#
# libstdcxx-devel_linu | 12.3 MB   | : 100% 1.0/1 [00:11<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | : 100% 1.0/1 [00:11<00:00,  2.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# quippy-0.9.14        | 6.4 MB    | : 100% 1.0/1 [00:11<00:00,  1.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ucx-1.18.0           | 7.2 MB    | : 100% 1.0/1 [00:11<00:00,  2.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:12<00:00,  3.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsanitizer-13.3.0  | 4.0 MB    | : 100% 1.0/1 [00:12<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | : 100% 1.0/1 [00:12<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.8 MB    | : 100% 1.0/1 [00:12<00:00,  2.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_impl_linux- | 5.4 MB    | : 100% 1.0/1 [00:13<00:00,  3.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | : 100% 1.0/1 [00:16<00:00,  1.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# \
# To enable CUDA support, UCX requires the CUDA Runtime library (libcudart).
# The library can be installed with the appropriate command below:
#
# * For CUDA 11, run:    conda install cudatoolkit cuda-version=11
# * For CUDA 12, run:    conda install cuda-cudart cuda-version=12
#
# If any of the packages you requested use CUDA then CUDA should already
# have been installed for you.
#
#
# |
# To enable CUDA support, please follow UCX's instruction above.
#
# To additionally enable NCCL support, run:    conda install nccl
#
#
# /

# %%
# Mount your Google Drive
from google.colab import drive
drive.mount("/content/drive")

# %%
# Create a working directory, possible to skip if you do not want to save your files
# !mkdir -p /content/drive/MyDrive/lammps_on_colab
# %cd /content/drive/MyDrive/lammps_on_colab

# %%
# Once everything is installed, load the libraries and files
import mdtraj as md
import py3Dmol
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lammps_logfile as lmp_log

# %%
# Remove existing files, run only if needed
# !rm -rf *.xyz *.in *.out *.lammps

# %%
# Get the LAMMPS input file that we need, uncomment the relevant files

# Argon modelled using LJ interactions, normalized units
# !wget -O argon_lj.in https://raw.githubusercontent.com/jingjieyeo/lammps_on_colab/main/examples/lennard_jones_argon/argon_lj.in

# Mixture of Argon and Neon using LJ interactions, normalized units
#!wget -O mix_lj.in https://raw.githubusercontent.com/jingjieyeo/lammps_on_colab/main/examples/lennard_jones_mixtures/mix_lj.in

# Aluminum using LJ interactions, real units
#!wget -O al_lj.in https://raw.githubusercontent.com/jingjieyeo/lammps_on_colab/main/examples/lennard_jones_aluminum/al_lj.in

# Tensile test on Aluminum using LJ interactions, real units
#!wget -O al_lj_tensile.in https://raw.githubusercontent.com/jingjieyeo/lammps_on_colab/main/examples/lennard_jones_aluminum/al_lj_tensile.in

# Polymer example using PMMA
#!wget -O pmma.zip https://raw.githubusercontent.com/jingjieyeo/lammps_on_colab/main/examples/pmma/pmma.zip
#!unzip -o pmma.zip -d ./pmma
#%cd pmma

# %%
# Run LAMMPS
# Argon
# !mpirun --allow-run-as-root lmp_mpi -in argon_lj.in

# Mixture
#!mpirun --allow-run-as-root lmp_mpi -in mix_lj.in

# Aluminum
#!mpirun --allow-run-as-root lmp_mpi -in al_lj.in

# Tensile test on Aluminum
#!mpirun --allow-run-as-root lmp_mpi -in al_lj_tensile.in

# Polymer example using PMMA
#!mpirun --allow-run-as-root lmp_mpi -in pmma.in
#!mpirun --allow-run-as-root lmp_mpi -in equilibration.in

# %%
# Have a look at the output from LAMMPS
# !cat log.lammps

# %%
# Plot LAMMPS thermo output
log = lmp_log.File("./log.lammps")

# Plot the variation of temperature with time
x = log.get("Step")
y = log.get("Temp")

plt.figure(figsize=(10, 5))
plt.title("Temperature")
plt.xlabel("No. of Steps")
plt.ylabel("Temperature")
plt.plot(x, y)
plt.show()

# %%
# Plot the variation of temperature with time
pe = log.get("PotEng")
ke = log.get("KinEng")
te = log.get("TotEng")

plt.figure(figsize=(10, 5))
plt.title("Energy")
plt.xlabel("No. of Steps")
plt.ylabel("Energy")
plt.plot(x, pe, label="Potential Energy")
plt.plot(x, ke, label="Kinetic Energy")
plt.plot(x, te, label="Total Energy")
plt.legend()
plt.show()

# %%
# Create the viewer
viewer = py3Dmol.view(width=400, height=400)

# Add all models to the viewer and set the frames for animation
viewer.addModelsAsFrames(open('equil.xyz', 'r').read(), 'xyz')
viewer.setBackgroundColor('white')
viewer.setStyle({'sphere': {'color':'green', "scale": 0.25}})

viewer.zoomTo()

# Set animation parameters
viewer.animate({'loop': 'forward'})

# Display the viewer
viewer.show()
